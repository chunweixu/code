# %%
def read_file(datafile):
    with open('test1.txt', 'r') as f:
        matrix = []
        for i in range(9):
            line = f.readline()
            
            ch_list = list(line)
            ch_list = [int(ch_list[i]) for i in range(9)]
            matrix.append(ch_list)
    return matrix
                
def check(row_index, col, number, matrix):
    for i in range(9):
        if(matrix[row_index][i] == number or matrix[i][col] == number):
            return False
        
    temprow = row_index/3
    tempcol = col/3
    for i in range(3):
        for j in range(3):
            if (matrix[temprow*3 + i][tempcol*3 + j] == number):
                return False
            
    return True

def printArray(matrix):
    for i in range(9):
        print [matrix[i][j] for j in range(9)]
    

def back_trace(i, j, matrix):
    if i==8 and j==9:
        print "Correct Answer."
        printArray(matrix)
        return
    
    if j == 9:
        print "Change row."
        i = i + 1
        j = 0
    
    if matrix[i][j] == 0:
        for k in range(1, 10):
            if check(i, j, k, matrix):
                matrix[i][j] = k
                back_trace(i, j+1, matrix)
                print '=================================================='
                //初始化该空格
                matrix[i][j] = 0
    else:
        back_trace(i, j+1, matrix)
        
if __name__ == "__main__":
    matrix = read_file('test2.txt')
    print matrix
    print "+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++"
    back_trace(0, 0, matrix)
# Out:
# [[0, 6, 0, 5, 9, 3, 0, 0, 0], [9, 0, 1, 0, 0, 0, 5, 0, 0], [0, 3, 0, 4, 0, 0, 0, 9, 0], [1, 0, 8, 0, 2, 0, 0, 0, 4], [4, 0, 0, 3, 0, 9, 0, 0, 1], [2, 0, 0, 0, 1, 0, 6, 0, 9], [0, 8, 0, 0, 0, 6, 0, 2, 0], [0, 0, 4, 0, 0, 0, 8, 0, 7], [0, 0, 0, 7, 8, 5, 0, 1, 0]]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# Change row.
# Change row.
# Change row.
# Correct Answer.
# [7, 6, 2, 5, 9, 3, 1, 4, 8]
# [9, 4, 1, 2, 7, 8, 5, 3, 6]
# [8, 3, 5, 4, 6, 1, 7, 9, 2]
# [1, 9, 8, 6, 2, 7, 3, 5, 4]
# [4, 7, 6, 3, 5, 9, 2, 8, 1]
# [2, 5, 3, 8, 1, 4, 6, 7, 9]
# [3, 8, 7, 1, 4, 6, 9, 2, 5]
# [5, 1, 4, 9, 3, 2, 8, 6, 7]
# [6, 2, 9, 7, 8, 5, 4, 1, 3]
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# Change row.
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
# Change row.
# ...
